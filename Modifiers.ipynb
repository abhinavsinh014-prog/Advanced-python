# %%
class person:
    def __init__(self, name, age):
        self.__name = name
        self.__age = age
    def get_name(self):
        return self.__name

# %%
getp = person("Abhinav", 22)
print(getp.get_name())  # This will print "Abhinav"
# Out:
# Abhinav

# %%
class son:
    def __init__(self, name, age):
        self._name = name
        self._age = age
# Out:
# Abhinav
