# %%
from sklearn.linear_model import LinearRegression

# %%
X = [[1],[2],[3],[4]]
y = [2,4,6,8]

mod = LinearRegression()
mod.fit(X,y)
mod.predict([[5]])
# Out:
# array([10.])

# %%
X = [[1],[2],[3],[4]]
y = [3,6,9,12]

mod = LinearRegression()
mod.fit(X,y)
mod.predict([[10]])
# Out:
# array([30.])
