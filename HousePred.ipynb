# %%
import pandas as pd
import streamlit as st
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
np.random.seed(42)
n_samples = 2000

sqft = np.random.normal(1800, 700, n_samples).clip(400, 6000)
bedrooms = np.random.randint(1, 6, n_samples)
bathrooms = np.random.randint(1, 4, n_samples) + np.random.choice([0, 0.5], n_samples)
age = np.random.uniform(0, 80, n_samples)
distance_to_city = np.random.uniform(0.5, 40, n_samples)
crime_rate = np.random.exponential(3, n_samples).clip(0, 25)
school_rating = np.random.uniform(1, 10, n_samples)

# %%
price = (
    50000
    + 180 * sqft
    + 8000 * bedrooms
    + 12000 * bathrooms
    - 800 * age
    - 1500 * distance_to_city
    - 2000 * crime_rate
    + 9000 * school_rating
    + np.random.normal(0, 25000, n_samples)
).clip(50000, None)

df = pd.DataFrame({
    "sqft": sqft,
    "bedrooms": bedrooms,
    "bathrooms": bathrooms,
    "age_years": age,
    "distance_to_city_miles": distance_to_city,
    "crime_rate": crime_rate,
    "school_rating": school_rating,
    "price": price
})
print("Dataset shape:", df.shape)
print("\nColumns:", list(df.columns))
print("\nFirst 5 rows:\n", df.head())
print("\nSummary statistics:\n", df.describe())

plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, fmt=".2f", cmap="coolwarm")
plt.title("Feature Correlation Heatmap")
plt.tight_layout()
plt.savefig("correlation_heatmap.png", dpi=120)
plt.close()

plt.figure(figsize=(7, 5))
plt.scatter(df["sqft"], df["price"], alpha=0.2, s=10)
plt.xlabel("Square Footage")
plt.ylabel("House Price (USD)")
plt.title("Square Footage vs House Price")
plt.tight_layout()
plt.savefig("income_vs_price.png", dpi=120)
plt.close()

X = df.drop(columns=["price"])
y = df["price"]

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33, random_state=42
)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

model = LinearRegression()
model.fit(X_train_scaled, y_train)

print("\nModel Intercept:", round(model.intercept_, 3))
coef_df = pd.DataFrame({
    "Feature": X.columns,
    "Coefficient": model.coef_
}).sort_values(by="Coefficient", key=abs, ascending=False)
print("\nFeature Coefficients (standardized):\n", coef_df)

y_pred = model.predict(X_test_scaled)

mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"\nMSE:  {mse:,.2f}")
print(f"RMSE: ${rmse:,.0f}  (typical prediction error in dollars)")
print(f"MAE:  ${mae:,.0f}")
print(f"R2:   {r2:.4f}")

plt.figure(figsize=(7, 6))
plt.scatter(y_test, y_pred, alpha=0.3, s=12)
plt.plot([y.min(), y.max()], [y.min(), y.max()], 'r--', linewidth=2, label="Perfect prediction")
plt.xlabel("Actual House Price (USD)")
plt.ylabel("Predicted House Price (USD)")
plt.title("Actual vs Predicted House Values")
plt.legend()
plt.tight_layout()
plt.savefig("actual_vs_predicted.png", dpi=120)
plt.close()

residuals = y_test - y_pred
plt.figure(figsize=(7, 5))
plt.scatter(y_pred, residuals, alpha=0.3, s=12)
plt.axhline(y=0, color='r', linestyle='--', linewidth=2)
plt.xlabel("Predicted House Price (USD)")
plt.ylabel("Residual (Actual - Predicted)")
plt.title("Residual Plot")
plt.tight_layout()
plt.savefig("residual_plot.png", dpi=120)
plt.close()

print("\nAll plots saved.")
# Out:
# Dataset shape: (2000, 8)
#
# Columns: ['sqft', 'bedrooms', 'bathrooms', 'age_years', 'distance_to_city_miles', 'crime_rate', 'school_rating', 'price']
#
# First 5 rows:
#            sqft  bedrooms  bathrooms  age_years  distance_to_city_miles  \
# 0  2147.699907         3        3.5  57.175687                7.658113
# 1  1703.214989         3        3.5  48.303421               32.506980
# 2  2253.381977         3        3.0  23.914092                5.834006
# 3  2866.120899         4        3.0  32.865312               19.011740
# 4  1636.092638         5        2.5  17.415984               37.573840
#
#    crime_rate  school_rating          price
# 0    1.165145       8.136121  536713.193151
# 1    0.848991       8.239568  398140.726142
# 2    0.027139       2.863763  493149.072928
# 3    0.805488       4.023225  631480.492708
# 4    0.444555       2.208146  367806.300054
#
# Summary statistics:
#                sqft     bedrooms    bathrooms    age_years  \
# count  2000.000000  2000.000000  2000.000000  2000.000000
# mean   1836.577658     3.019500     2.259000    38.824295
# std     679.712108     1.417436     0.847955    22.958395
# min     400.000000     1.000000     1.000000     0.019280
# 25%    1364.136669     2.000000     1.500000    18.823636
# 50%    1831.284159     3.000000     2.500000    38.149832
# 75%    2278.084315     4.000000     3.000000    58.403640
# max    4496.912043     5.000000     3.500000    79.936584
#
#        distance_to_city_miles   crime_rate  school_rating          price
# count             2000.000000  2000.000000    2000.000000    2000.000000
# mean                20.128181     3.064510       5.454914  413729.269913
# std                 11.183987     3.082895       2.649130  131196.793043
# min                  0.502087     0.000473       1.010833   62197.974893
# 25%                 10.672210     0.873974       3.105567  323528.651624
# 50%                 20.082846     2.064650       5.396858  409966.864183
# 75%                 29.563007     4.296015       7.811402  503486.409736
# max                 39.980455    24.078535       9.989603  844067.908994
#
# Model Intercept: 408343.049
#
# Feature Coefficients (standardized):
#                    Feature    Coefficient
# 0                    sqft  121542.145877
# 6           school_rating   23025.665767
# 3               age_years  -18012.176099
# 4  distance_to_city_miles  -17239.469547
# 2               bathrooms   10522.788327
# 1                bedrooms   10326.367572
# 5              crime_rate   -5380.557902
#
# MSE:  598,030,007.92
# RMSE: $24,455  (typical prediction error in dollars)
# MAE:  $19,220
# R2:   0.9668
#
# All plots saved.

# %%
st.title("House prediction")
sqft = st.number_input("Square feet")
bedrooms = st.number_input("Bedrooms")
bathrooms = st.number_input("Bathrooms")
age_years = st.number_input("age")
distance_to_city = st.number_input("distance_to_city")
crime_rate = st.number_input("Crime rate")
school_rating = st.number_input("School rating (1-10)")
# Out:
# 2026-08-25 17:47:36.487 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 17:47:36.853
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /usr/local/lib/python3.13/dist-packages/colab_kernel_launcher.py [ARGUMENTS]
# 2026-08-25 17:47:36.855 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 17:47:36.858 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 17:47:36.859 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 17:47:36.860 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 17:47:36.861 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 17:47:36.863 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 17:47:36.865 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 17:47:36.868 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 17:47:36.869 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 17:47:36.872 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 17:47:36.872 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 17:47:36.876 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 17:47:36.878 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 17:47:36.880 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 17:47:36.882 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 17:47:36.884 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 17:47:36.886 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 17:47:36.887 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 17:47:36.888 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 17:47:36.890 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 17:47:36.891 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 17:47:36.893 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 17:47:36.897 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 17:47:36.898 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 17:47:36.899 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 17:47:36.902 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 17:47:36.903 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 17:47:36.904 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 17:47:36.908 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 17:47:36.910 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 17:47:36.911 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 17:47:36.911 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 17:47:36.912 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 17:47:36.914 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 17:47:36.915 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 17:47:36.917 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 17:47:36.918 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 17:47:36.920 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 17:47:36.923 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 17:47:36.925 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 17:47:36.925 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 17:47:36.926 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 17:47:36.928 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 17:47:36.931 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
print("\nEnter details for the house you want to price:")
new_house = {
    "sqft": sqft,
    "bedrooms": bedrooms,
    "bathrooms": bathrooms,
    "age_years": age_years,
    "distance_to_city_miles": distance_to_city,
    "crime_rate": crime_rate,
    "school_rating": school_rating
}

new_house_df = pd.DataFrame({k: [v] for k, v in new_house.items()})

new_house_df = new_house_df[X.columns]
new_house_scaled = scaler.transform(new_house_df)
predicted_price = model.predict(new_house_scaled)[0]

print("\n--- New House Prediction ---")
for feature, value in new_house.items():
    print(f"{feature}: {value}")
print(f"Predicted Price: ${predicted_price:,.0f}")
# Out:
# Enter details for the house you want to price:
#
# --- New House Prediction ---
# sqft: 0.0
# bedrooms: 0.0
# bathrooms: 0.0
# age_years: 0.0
# distance_to_city_miles: 0.0
# crime_rate: 0.0
# school_rating: 0.0
# Predicted Price: $51,017
