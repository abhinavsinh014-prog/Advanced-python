# %%
f = lambda x,y : x+y

# %%
f(2,3)
# Out:
# 5

# %%
sti = lambda s : len(s)
sti("abhinav")
# Out:
# 7

# %%
dfs = [1,2,3,4,5]
multiply = list(map(lambda x: x**2, dfs))
print(multiply)
# Out:
# [1, 4, 9, 16, 25]

# %%
dfs = [1,2,3,4,5]
list(filter(lambda x: x % 2 == 0, dfs))
# Out:
# [2, 4]
