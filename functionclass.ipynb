# %%
from dataclasses import dataclass

@dataclass
class ring:
    name:str
    wins:int
    debut:int

rinfs = ring("john cena", 17, 2002)

# %%
rinfs.name
# Out:
# 'john cena'

# %%
rinfs.wins
# Out:
# 17
